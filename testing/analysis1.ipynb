# %% [markdown]
# <div style="
#     background-color: #f7f7f7;
#     background-image: url('data:image/svg+xml;base64,...'), url('data:image/svg+xml;base64,...') ;
#     background-position: left bottom, right top;
#     background-repeat: no-repeat,  no-repeat;
#     background-size: auto 60px, auto 160px;
#     border-radius: 5px;
#     box-shadow: 0px 3px 1px -2px rgba(0, 0, 0, 0.2), 0px 2px 2px 0px rgba(0, 0, 0, 0.14), 0px 1px 5px 0px rgba(0,0,0,.12);">
#
# <h1 style="
#     color: #2a4cdf;
#     font-style: normal;
#     font-size: 2.25rem;
#     line-height: 1.4em;
#     font-weight: 600;
#     padding: 30px 200px 0px 30px;"
# >analysis1</h1>
# </div>
#
# This notebook was generated by and is linked to a NOMAD `JupyterAnalysis`
# ELN entry.
#
# Run the next two cells to load the linked ELN entry into the variable:
# `analysis`. The analysis inputs can be accessed by `analysis.inputs`.
#
# For more information on using `JupyterAnalysis`, such as adding back
# results to the analysis entry, see the NOMAD Analysis plugin
# [documentation](https://fairmat-nfdi.github.io/nomad-analysis/).

# %%
# NOMAD Analysis Metadata - DO NOT EDIT
NOMAD_ANALYSIS_ENTRY_ID = 'hY5Hw09eQUWnEP1GvtOj8tcS1pl1'
NOMAD_ANALYSIS_BASE_URL = 'http://localhost:8000/nomad-oasis/api/v1'

# %%
from nomad_analysis.utils import get_entry_data

analysis = await get_entry_data(
    entry_id=NOMAD_ANALYSIS_ENTRY_ID,
    url=NOMAD_ANALYSIS_BASE_URL,
    username='sarthakdevelop',
    password='1nH@rmony01',
)
# Out:
# Fetching remote uploads...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 from nomad_analysis.utils import get_entry_data
#       2
# ----> 3 analysis = await get_entry_data(
#       4     entry_id=NOMAD_ANALYSIS_ENTRY_ID,
#       5     url=NOMAD_ANALYSIS_BASE_URL,
#       6     username='sarthakdevelop',
#
# File ~/repositories/fairmat/dev_distro/packages/nomad-analysis/src/nomad_analysis/utils.py:141, in get_entry_data(entry_id, url, username, password)
#     138     entry_list = await a_query.async_download(1)
#     139 except Exception as e:
#     140     # print(f'Encountered error: {e}')
# --> 141     raise e
#     143 if not entry_list:
#     144     print(
#     145         f'Entry not found for entry_id: "{entry_id}", url: "{url}", and user: '
#     146         f'"{username}".'
#     147     )
#
# File ~/repositories/fairmat/dev_distro/packages/nomad-analysis/src/nomad_analysis/utils.py:138, in get_entry_data(entry_id, url, username, password)
#     128 try:
#     129     a_query = ArchiveQuery(
#     130         query={
#     131             'entry_id:any': [entry_id],
#    (...)    136         password=password,
#     137     )
# --> 138     entry_list = await a_query.async_download(1)
#     139 except Exception as e:
#     140     # print(f'Encountered error: {e}')
#     141     raise e
#
# File ~/repositories/fairmat/dev_distro/packages/nomad-FAIR/nomad/client/archive.py:560, in ArchiveQuery.async_download(self, number, as_plain_dict)
#     557     number = await self.async_fetch()
#     558 elif pending_size < number:
#     559     # if not sufficient fetched entries, fetch first
# --> 560     await self.async_fetch(number - pending_size)
#     562 return await self._download_async(number, as_plain_dict=as_plain_dict)
#
# File ~/repositories/fairmat/dev_distro/packages/nomad-FAIR/nomad/client/archive.py:540, in ArchiveQuery.async_fetch(self, number)
#     534 """
#     535 Asynchronous interface for use in a running event loop.
#     536 """
#     538 print('Fetching remote uploads...')
# --> 540 return await self._fetch_async(number)
#
# File ~/repositories/fairmat/dev_distro/packages/nomad-FAIR/nomad/client/archive.py:322, in ArchiveQuery._fetch_async(self, number)
#     316     response_json = response.json()
#     317     reason = (
#     318         response_json.get('description')
#     319         or response_json.get('detail')
#     320         or 'unknown reason'
#     321     )
# --> 322     raise ValueError(
#     323         f'Server returns {response.status_code}: {reason}'
#     324     )
#     325 if response.status_code in (500, 502, 504):
#     326     if num_retry > self._retry:
#
# ValueError: Server returns 401: Could not validate credentials.
# The user provided keycloak public key does not exist.
# Does the UI use the right realm?

# %%
from nomad import config

config.client.user
# Out:
# 'sarthakdevelop'
